# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('filepath\\KC=F.csv',parse_dates=['Date'])

# %%
plt.plot(data.Date, data.Close)
plt.show()

# %%
plt.plot(data.Date, data.Volume)
plt.show()
